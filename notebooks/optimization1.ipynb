# %%
# %load_ext autoreload
# %autoreload 2

# %%
import mypkg
mypkg.__file__

# %%
import importlib
import mypkg

importlib.reload(mypkg)
mypkg.square(5)

# %%
import sys
from mypkg.optimization1 import compute

compute(10)
